# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cargar en memoria virtual los archivos de classes.txt y convert_annotations.py

# %% [markdown]
# **Open Images Dataset V6 +**

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git  # Clonar repositorio
# Out:
# fatal: destination path 'OIDv4_ToolKit' already exists and is not an empty directory.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt    # Entrar a requirements e instalar lo que falta

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Bicycle --type_csv train --limit 100   # Lo primero se pone de ley, lo segundo es con base en la busqueda en open images de google
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Bicycle.
#
# Bicycle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 17631 online images for train.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 98 images in train.
# 100% 98/98 [01:04<00:00,  1.52it/s]
#     [INFO] | Done!
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Bicycle --type_csv validation --limit 50
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Bicycle.
#
# Bicycle
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 242 online images for validation.
#     [INFO] | Limiting to 50 images.
#     [INFO] | Download of 41 images in validation.
# 100% 41/41 [00:33<00:00,  1.21it/s]
#     [INFO] | Done!
# ...

# %%
# !python /content/convert_annotations.py      # Convierte el conjunto de entrenamiento y validacion a imagen-etiqueta
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Bicycle
# 100% 298/298 [00:12<00:00, 23.85it/s]
# Currently in subdirectory: validation
# Converting annotations for class:  Bicycle
# 100% 91/91 [00:02<00:00, 33.25it/s]

# %%
import shutil          # Separar los archivos, para facil acceso
shutil.rmtree('/content/OID/Dataset/train/Bicycle/Label')    # Quitar la carpeta de label, para entrenamiento

# %%
shutil.rmtree('/content/OID/Dataset/validation/Bicycle/Label')    # Quitar la carpeta de label, para validacion

# %%
shutil.copytree('/content/OID/Dataset/train/Bicycle', '/content/obj')   # Copiar del conjunto de entrenamiento lo de bicycle (datos y etiquetas) copiar a una carpeta llamada "obj"
# Out:
# '/content/obj'

# %%
shutil.copytree('/content/OID/Dataset/validation/Bicycle', '/content/test')   # Copiar del conjunto de entrenamiento lo de bicycle (datos y etiquetas) copiar a una carpeta llamada "test"
# Out:
# '/content/test'

# %% [markdown]
# # **Zip datasets**

# %%
#Train test
import os
import zipfile

# Declare the function to return all file paths of the particular directory
def retrieve_file_paths(dirName):
 
  # setup file paths variable
  filePaths = []
   
  # Read all directory, subdirectories and file lists
  for root, directories, files in os.walk(dirName):
    for filename in files:
        # Create the full filepath by using os module.
        filePath = os.path.join(root, filename)
        filePaths.append(filePath)
         
  # return all paths
  return filePaths

#Call to the function
dataset = ['obj']
for dir_name in dataset:

  # Call the function to retrieve all files and folders of the assigned directory
  filePaths = retrieve_file_paths(dir_name)
    
  # printing the list of all files to be zipped
  print('The following list of files will be zipped:')
  #for fileName in filePaths:
  #  print(fileName)
      
  # writing files to a zipfile
  zip_file = zipfile.ZipFile('/content/drive/My Drive/Colab Notebooks/Ai Lab School/SESION 10/yolov4/2._obj.zip', 'w')
  with zip_file:
    # writing each file one by one
    for file in filePaths:
      zip_file.write(file)
# Out:
# The following list of files will be zipped:

# %%
#Validation test
import os
import zipfile

# Declare the function to return all file paths of the particular directory
def retrieve_file_paths(dirName):
 
  # setup file paths variable
  filePaths = []
   
  # Read all directory, subdirectories and file lists
  for root, directories, files in os.walk(dirName):
    for filename in files:
        # Create the full filepath by using os module.
        filePath = os.path.join(root, filename)
        filePaths.append(filePath)
         
  # return all paths
  return filePaths

#Call to the function
dataset = ['test']
for dir_name in dataset:

  # Call the function to retrieve all files and folders of the assigned directory
  filePaths = retrieve_file_paths(dir_name)
    
  # printing the list of all files to be zipped
  print('The following list of files will be zipped:')
  #for fileName in filePaths:
  #  print(fileName)
      
  # writing files to a zipfile
  zip_file = zipfile.ZipFile('/content/drive/My Drive/Colab Notebooks/Ai Lab School/SESION 10/yolov4/2._test.zip', 'w')
  with zip_file:
    # writing each file one by one
    for file in filePaths:
      zip_file.write(file)
# Out:
# The following list of files will be zipped:
