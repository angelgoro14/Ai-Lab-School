# %%
# Ejercicio de MNIST pero en red convolucional
from tensorflow.keras import layers
from tensorflow.keras import models

# Arquitectura de la red
model = models.Sequential()
# Para imagenes se requiere utilizar la capa Conv2D
# .....Conv2D(Numero de mapas de caracteristicas, (Matriz cuadrada de pesos para cada mapa de caracteristicas)
# Input shape (28, 28, 1) --> Imagenes de 28x28, el '1' refiere que es escala de grises.  
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))   
# Mediante una matriz de 2x2 o tambien llamados filtros se van a refinar los datos de la capa anterior
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
# Aplanar la informacion que se obtuvo
model.add(layers.Flatten())
# Se define una red neuronal densamente conectada
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# ...

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Tensor (60000, 28, 28, 1)--> Representacion general de matrices (imagenes totales, ancho, largo, tipo de imagen)
train_images = train_images.reshape((60000, 28, 28, 1))
# Normalizacion
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

# Conversion a un vector binario
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 49s 51ms/step - loss: 0.1760 - accuracy: 0.9451
# Epoch 2/5
# 938/938 [==============================] - 48s 51ms/step - loss: 0.0489 - accuracy: 0.9846
# Epoch 3/5
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0348 - accuracy: 0.9895
# Epoch 4/5
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0262 - accuracy: 0.9915
# Epoch 5/5
# 938/938 [==============================] - 46s 50ms/step - loss: 0.0196 - accuracy: 0.9941

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0381 - accuracy: 0.9889

# %% [markdown]
# **CUANDO SE TENGA UN PROBLEMA DE CLASIFICACION DE IMAGENES, SE DEBE USAR UNA RED CONVOLUCIONAL POR TODOS LOS BENEFICIOS QUE APORTA**
