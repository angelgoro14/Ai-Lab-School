# %%
#Importamos la base de datos Fashion MNIST
from tensorflow.keras.datasets import cifar10

# %%
#Extraemos los conjuntos de entrenamiento y prueba
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 12s 0us/step

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# # **Definimos la arquitectura de CNN**

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))) #Capa convolucional 1
model.add(layers.MaxPooling2D((2, 2))) #Capa max pooling 1
model.add(layers.Conv2D(64, (3, 3), activation='relu')) #Capa convolucional 2
model.add(layers.MaxPooling2D((2, 2))) #Capa max-pooling 2
model.add(layers.Conv2D(128, (3, 3), activation='relu')) #Capa convolucional 3
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# # **Preprocesamiento de las imágenes y sus clases correspondientes**

# %%
from tensorflow.keras.utils import to_categorical


train_images = train_images.reshape((50000, 32, 32, 3))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 32, 32, 3))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# # **Entrenamiento**

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 66s 167ms/step - loss: 1.5963 - accuracy: 0.4181
# Epoch 2/50
# 391/391 [==============================] - 65s 166ms/step - loss: 1.2228 - accuracy: 0.5630
# Epoch 3/50
# 391/391 [==============================] - 67s 170ms/step - loss: 1.0538 - accuracy: 0.6286
# Epoch 4/50
# 391/391 [==============================] - 66s 168ms/step - loss: 0.9376 - accuracy: 0.6711
# Epoch 5/50
# 391/391 [==============================] - 66s 170ms/step - loss: 0.8555 - accuracy: 0.7030
# Epoch 6/50
# 391/391 [==============================] - 65s 165ms/step - loss: 0.7882 - accuracy: 0.7267
# Epoch 7/50
# 391/391 [==============================] - 65s 166ms/step - loss: 0.7214 - accuracy: 0.7503
# Epoch 8/50
# 391/391 [==============================] - 64s 165ms/step - loss: 0.6692 - accuracy: 0.7671
# Epoch 9/50
# 391/391 [==============================] - 65s 167ms/step - loss: 0.6225 - accuracy: 0.7826
# Epoch 10/50
# 391/391 [==============================] - 65s 166ms/step - loss: 0.5803 - accuracy: 0.7973
# Epoch 11/50
# 391/391 [==============================] - 65s 166ms/step - loss: 0.5370 - accuracy: 0.8106
# Epoch 12/50
# 391/391 [==============================] - 66s 168ms/step - loss: 0.4969 - accuracy: 0.8263
# Epoch 13/50
# 391/391 [==============================] - 64s 164ms/step - loss: 0.4530 - accuracy: 0.8422
# Epoch 14/50
# 391/391 [==============================] - 63s 161ms/step - loss: 0.4105 - accuracy: 0.8574
# Epoch 15/50
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3736 - accuracy: 0.8690
# Epoch 16/50
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3372 - accuracy: 0.8814
# Epoch 17/50
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3004 - accuracy: 0.8961
# Epoch 18/50
# 391/391 [==============================] - 63s 161ms/step - loss: 0.2795 - accuracy: 0.9031
# Epoch 19/50
# 391/391 [==============================] - 63s 161ms/step - loss: 0.2480 - accuracy: 0.9142
# Epoch 20/50
# 391/391 [==============================] - 63s 162ms/step - loss: 0.2154 - accuracy: 0.9255
# Epoch 21/50
# 391/391 [==============================] - 63s 162ms/step - loss: 0.1957 - accuracy: 0.9307
